# %%
import json
import time
from pathlib import Path

import pandas as pd
import requests
from bs4 import BeautifulSoup
from selenium.webdriver import Chrome
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
from tqdm import tqdm

# %%
urls = {
    'Red Wine': 'https://www.laithwaites.co.uk/wines/Red-Wine/_/N-1z141we',
    'White Wine': 'https://www.laithwaites.co.uk/wines/White-Wine/_/N-1z141yb',
    'Sparkling': 'https://www.laithwaites.co.uk/wines/Sparkling/_/N-1z141tg',
    'Rose Wine': 'https://www.laithwaites.co.uk/wines/Ros%C3%A9-Wine/_/N-1z141yi',
    'Fortified': 'https://www.laithwaites.co.uk/wines/Fortified/_/N-1z12ly0',
    'Dessert Wine': 'https://www.laithwaites.co.uk/wines/Dessert-Wine/_/N-1z141jk'
}

# %%
driver = Chrome()
listing_urls = []
for winetype,url in urls.items():
    #url = 'https://www.laithwaites.co.uk/wines/White-Wine/_/N-1z141yb'
    driver.get(url)
    time.sleep(0.5)
    try:
        cookie_button = driver.find_element(By.XPATH,'//button[@id="onetrust-accept-btn-handler"]')
        if cookie_button.is_displayed():
            cookie_check = True
    except:
        cookie_check = False
    
    if cookie_check:
        cookie_button.click()

    
    select = Select(driver.find_element(By.XPATH,'//select[@id="numPerPage"]'))
    select.select_by_value('50')

    while True:
        product_wrappers = driver.find_elements(
                By.XPATH,
                '//div[contains(@class, "product-wrapper")]',
            )
        #print(len(product_wrappers))

        for product_wrapper in product_wrappers:
            listing = product_wrapper.find_element(By.XPATH,'.//a')
            listing_urls.append([winetype, listing.get_attribute('href')])
        print(len(listing_urls))
        
        try:
            next_button = driver.find_element(By.XPATH,'//a[@id="nextPage"]')
            if next_button.is_displayed():
                click_next = True
        except:
            click_next = False
        
        if click_next:
            try:
                next_button.click()
            except:
                break
        else:
            print('End of type' + winetype)
            break
# Out:
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 673
# 723
# 773
# 823
# 873
# 923
# 973
# 1023
# 1062
# 1112
# 1154
# 1204
# End of typeRose Wine
# 1231
# End of typeFortified
# 1236
# End of typeDessert Wine

# %%
listing_urls_path = Path('./data/url/laithwaites_listings.json')
export_path = './data/scrapped/virginwines_listings.csv'
with open(listing_urls_path, 'w') as f:
        json.dump(listing_urls, f, indent=4)

# %%
def clean_text_data(value):
    return value.strip().replace('\n', '').replace('\t', '').replace(':', '')


def get_price(soup):
    price_str = soup.find('p', class_='price h3 m-0 text-sanchez text-lh-1').text
    return float(price_str.replace('£', ''))


def get_bottle_size(li_tags):
    bottle_size_raw = clean_text_data(li_tags[2].find('span').text)

    if 'cl' in bottle_size_raw:
        return float(bottle_size_raw.replace('cl', ''))
    elif bottle_size_raw == 'Magnum 1.5L':
        return 150
    else:
        raise ValueError(f'edge case found {bottle_size_raw}')

# %%
def try_catch(web_element):
    try:
        return web_element.text
    except:
        return '0'

# %%
wine_info_all = []
listing_urls_path = Path('./data/url/laithwaites_listings.json')
listing_urls = json.load(open(listing_urls_path))
for winetype,listing_url in tqdm(listing_urls):
    listing_page = requests.get(listing_url)
    soup = BeautifulSoup(listing_page.content, 'html.parser')
    wine_data = {}
    #name
    wine_data['name'] = clean_text_data(try_catch(soup.find('h1', {'class' : 'prod-name'})))
    if wine_data['name'].split(' ')[-1].lower() == 'mix' or wine_data['name'].split(' ')[0].lower() == 'mystery':
        wine_data['Mix Case?'] = 1
    else:
        wine_data['Mix Case?'] = 0
        wine_infor_left = soup.find('div', {'class' : 'col-lg-6 col-sm-6 col-md-6 no-pad-left'}).find_all('li')
        wine_infor_right = soup.find('div', {'class' : 'col-lg-6 col-sm-6 col-md-6 no-pad'}).find_all('li')
        #abv
        wine_data['abv'] = clean_text_data(try_catch(wine_infor_right[0].find('div', {'class' : 'detail-text'}))).split(' ')[0].replace('%', '')
        #year
        wine_data['year'] = wine_data['name'].split(' ')[-1]
        #size
        wine_data['size'] = float(clean_text_data(try_catch(wine_infor_right[2].find('div', {'class' : 'detail-text'}))).split(' ')[0])
        #country
        #print(wine_infor_left)
        for a in wine_infor_left:
            if a.find('span').attrs['class'] == ['pull-left', 'icons', 'country-icon']:
                wine_data['country'] = clean_text_data(
                    try_catch(
                        a.find('div', {'class' : 'detail-text'}).find('a')
                        )
                    )
        #wine_type
        wine_data['wine_type'] = winetype
        #wine_data['wine_type_detail'] = clean_text_data(wine_infor_left[0].find('div', {'class' : 'detail-text'}).text)
        #price
        try:
            wine_data['price'] = float(soup.find('span', {'class' : 'price-per-bottle'}).text.replace('£', ''))
        except:
            wine_data['price'] = None
        #num_review
        wine_data['num_review'] = try_catch(soup.find('span', {'class' : 'no-reviews'})).replace('(', '').replace(')', '').split(' ')[0]
        #rating
        wine_data['rating'] = try_catch(soup.find('span', {'class' : 'rating-score'})).split(' ')[0]
        wine_data['url'] = listing_url
        #print(wine_data)
    wine_info_all.append(wine_data)
# Out:
# 100%|██████████| 1236/1236 [15:43<00:00,  1.31it/s]

# %%
wine_info_all
# Out:
# [{'name': 'Cabalié 2021',
#   'Mix Case?': 0,
#   'abv': '13.0',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 11.99,
#   'num_review': '7475',
#   'rating': '4.5',
#   'url': 'https://www.laithwaites.co.uk/product/Cabali%C3%A9-2021/0022621'},
#  {'name': 'The Black Stump Durif Shiraz 2021',
#   'Mix Case?': 0,
#   'abv': '14.5',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Australia',
#   'wine_type': 'Red Wine',
#   'price': 11.99,
#   'num_review': '7445',
#   'rating': '4.5',
#   'url': 'https://www.laithwaites.co.uk/product/The-Black-Stump-Durif-Shiraz-2021/0002421'},
#  {'name': 'Vinha do Fava Reserva 2020',
#   'Mix Case?': 0,
#   'abv': '14.5',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'Portugal',
#   'wine_type': 'Red Wine',
#   'price': 15.49,
#   'num_review': '544',
#   'rating': '4.5',
#   'url': 'https://www.laithwaites.co.uk/product/Vinha-do-Fava-Reserva-2020/3943720'},
#  {'name': 'w/o Organic Frappato 2021',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Italy',
#   'wine_type': 'Red Wine',
#   'price': 11.99,
#   'num_review': '158',
#   'rating': '3.8',
#   'url': 'https://www.laithwaites.co.uk/product/w/o-Organic-Frappato-2021/4160221'},
#  {'name': 'Cabalié (1 Litre Wine Box) 2021',
#   'Mix Case?': 0,
#   'abv': '13.0',
#   'year': '2021',
#   'size': 1000.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 9.99,
#   'num_review': '14',
#   'rating': '4.8',
#   'url': 'https://www.laithwaites.co.uk/product/Cabali%C3%A9-(1-Litre-Wine-Box)-2021/4251121'},
#  {'name': 'Il Papavero NV',
#   'Mix Case?': 0,
#   'abv': '12.5',
#   'year': 'NV',
#   'size': 750.0,
#   'country': 'Italy',
#   'wine_type': 'Red Wine',
#   'price': 8.99,
#   'num_review': '1618',
#   'rating': '3.7',
#   'url': 'https://www.laithwaites.co.uk/product/Il-Papavero-2021/0003720'},
#  {'name': 'Aluado Alicante Bouschet 2021',
#   'Mix Case?': 0,
#   'abv': '12.5',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Portugal',
#   'wine_type': 'Red Wine',
#   'price': 10.99,
#   'num_review': '1969',
#   'rating': '4.5',
#   'url': 'https://www.laithwaites.co.uk/product/Aluado-Alicante-Bouschet-2021/1549721'},
#  {'name': 'The Great Bonza Reserve Shiraz Cabernet Sauvignon 2019',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2019',
#   'size': 750.0,
#   'country': 'Australia',
#   'wine_type': 'Red Wine',
#   'price': 12.99,
#   'num_review': '510',
#   'rating': '4.2',
#   'url': 'https://www.laithwaites.co.uk/product/The-Great-Bonza-Reserve-Shiraz-Cabernet-Sauvignon-2019/3052019'},
#  {'name': 'Cabalié Cuvée Vieilles Vignes 2021',
#   'Mix Case?': 0,
#   'abv': '13.0',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 14.99,
#   'num_review': '5305',
#   'rating': '4.5',
#   'url': 'https://www.laithwaites.co.uk/product/Cabali%C3%A9-Cuv%C3%A9e-Vieilles-Vignes-2021/1468521'},
#  {'name': 'The Waxed Bat 2021',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Argentina',
#   'wine_type': 'Red Wine',
#   'price': 11.99,
#   'num_review': '2650',
#   'rating': '4.1',
#   'url': 'https://www.laithwaites.co.uk/product/The-Waxed-Bat-2021/0125021'},
#  {'name': 'Rocksand Shiraz 2020',
#   'Mix Case?': 0,
#   'abv': '14.5',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'Portugal',
#   'wine_type': 'Red Wine',
#   'price': 11.99,
#   'num_review': '1230',
#   'rating': '4.5',
#   'url': 'https://www.laithwaites.co.uk/product/Rocksand-Shiraz-2020/3287520'},
#  {'name': 'Rex Mundi Shiraz Grenache 2021',
#   'Mix Case?': 0,
#   'abv': '13.0',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 11.99,
#   'num_review': '2840',
#   'rating': '4.4',
#   'url': 'https://www.laithwaites.co.uk/product/Rex-Mundi-Shiraz-Grenache-2021/1419121'},
#  {'name': 'Château Grand Bourry Costières de Nîmes 2021',
#   'Mix Case?': 0,
#   'abv': '13.0',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 11.99,
#   'num_review': '4',
#   'rating': '4.0',
#   'url': 'https://www.laithwaites.co.uk/product/Ch%C3%A2teau-Grand-Bourry-Costi%C3%A8res-de-N%C3%AEmes-2021/4094721'},
#  {'name': 'Opi Malbec 2021',
#   'Mix Case?': 0,
#   'abv': '13.0',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Argentina',
#   'wine_type': 'Red Wine',
#   'price': 10.99,
#   'num_review': '2761',
#   'rating': '4.0',
#   'url': 'https://www.laithwaites.co.uk/product/Opi-Malbec-2021/2582521'},
#  {'name': 'Pillastro Primitivo 2021',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Italy',
#   'wine_type': 'Red Wine',
#   'price': 11.99,
#   'num_review': '5639',
#   'rating': '4.4',
#   'url': 'https://www.laithwaites.co.uk/product/Pillastro-Primitivo-2021/0016921'},
#  {'name': 'Clarendelle Bordeaux Inspired by Haut-Brion 2016',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2016',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 19.99,
#   'num_review': '6',
#   'rating': '4.0',
#   'url': 'https://www.laithwaites.co.uk/product/Clarendelle-Bordeaux-Inspired-by-Haut-Brion-2016/0974916'},
#  {'name': "McPherson Don't Tell Gary Shiraz 2019",
#   'Mix Case?': 0,
#   'abv': '14.5',
#   'year': '2019',
#   'size': 750.0,
#   'country': 'Australia',
#   'wine_type': 'Red Wine',
#   'price': 16.49,
#   'num_review': '51',
#   'rating': '4.1',
#   'url': "https://www.laithwaites.co.uk/product/McPherson-Don't-Tell-Gary-Shiraz-2019/3672019"},
#  {'name': 'Posada del Rey Tinto NV',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': 'NV',
#   'size': 750.0,
#   'country': 'Spain',
#   'wine_type': 'Red Wine',
#   'price': 7.99,
#   'num_review': '639',
#   'rating': '3.3',
#   'url': 'https://www.laithwaites.co.uk/product/Posada-del-Rey-Tinto-2019/0004220'},
#  {'name': 'McPherson The Full Fifteen 2021',
#   'Mix Case?': 0,
#   'abv': '15.0',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Australia',
#   'wine_type': 'Red Wine',
#   'price': 11.99,
#   'num_review': '2193',
#   'rating': '4.3',
#   'url': 'https://www.laithwaites.co.uk/product/McPherson-The-Full-Fifteen-2021/0017321'},
#  {'name': 'The Dip 2021',
#   'Mix Case?': 0,
#   'abv': '14.5',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Spain',
#   'wine_type': 'Red Wine',
#   'price': 10.99,
#   'num_review': '173',
#   'rating': '4.2',
#   'url': 'https://www.laithwaites.co.uk/product/The-Dip-2021/4159121'},
#  {'name': 'Ermita de San Lorenzo Gran Selección 2015',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2015',
#   'size': 750.0,
#   'country': 'Spain',
#   'wine_type': 'Red Wine',
#   'price': 12.99,
#   'num_review': '406',
#   'rating': '3.3',
#   'url': 'https://www.laithwaites.co.uk/product/Ermita-de-San-Lorenzo-Gran-Selecci%C3%B3n-2015/0352715'},
#  {'name': 'Lobo e Falcão 2021',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Portugal',
#   'wine_type': 'Red Wine',
#   'price': 11.99,
#   'num_review': '2064',
#   'rating': '4.4',
#   'url': 'https://www.laithwaites.co.uk/product/Lobo-e-Falc%C3%A3o-2021/1948221'},
#  {'name': 'Barón de Barbón Oak Aged Rioja 2020',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'Spain',
#   'wine_type': 'Red Wine',
#   'price': 11.99,
#   'num_review': '2838',
#   'rating': '3.7',
#   'url': 'https://www.laithwaites.co.uk/product/Bar%C3%B3n-de-Barb%C3%B3n-Oak-Aged-Rioja-2020/0002320'},
#  {'name': 'Ognissole Organic Primitivo 2019',
#   'Mix Case?': 0,
#   'abv': '15.0',
#   'year': '2019',
#   'size': 750.0,
#   'country': 'Italy',
#   'wine_type': 'Red Wine',
#   'price': 16.99,
#   'num_review': '12',
#   'rating': '3.8',
#   'url': 'https://www.laithwaites.co.uk/product/Ognissole-Organic-Primitivo-2019/4213819'},
#  {'name': 'Stones & Bones 2020',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'Portugal',
#   'wine_type': 'Red Wine',
#   'price': 11.99,
#   'num_review': '1758',
#   'rating': '4.2',
#   'url': 'https://www.laithwaites.co.uk/product/Stones-&-Bones-2020/2267520'},
#  {'name': "Terres d'Arboras 2021",
#   'Mix Case?': 0,
#   'abv': '13.0',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 13.49,
#   'num_review': '72',
#   'rating': '4.5',
#   'url': "https://www.laithwaites.co.uk/product/Terres-d'Arboras-2021/4147121"},
#  {'name': 'Vinha do Fava Touriga Nacional 2020',
#   'Mix Case?': 0,
#   'abv': '14.5',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'Portugal',
#   'wine_type': 'Red Wine',
#   'price': 11.99,
#   'num_review': '2442',
#   'rating': '4.3',
#   'url': 'https://www.laithwaites.co.uk/product/Vinha-do-Fava-Touriga-Nacional-2020/3107520'},
#  {'name': 'Dark Corner Durif Shiraz 2021',
#   'Mix Case?': 0,
#   'abv': '14.5',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Australia',
#   'wine_type': 'Red Wine',
#   'price': 11.99,
#   'num_review': '1956',
#   'rating': '4.4',
#   'url': 'https://www.laithwaites.co.uk/product/Dark-Corner-Durif-Shiraz-2021/2161521'},
#  {'name': 'Ringland Shiraz 2019',
#   'Mix Case?': 0,
#   'abv': '15.0',
#   'year': '2019',
#   'size': 750.0,
#   'country': 'Australia',
#   'wine_type': 'Red Wine',
#   'price': 17.99,
#   'num_review': '4',
#   'rating': '4.8',
#   'url': 'https://www.laithwaites.co.uk/product/Ringland-Shiraz-2019/4210919'},
#  {'name': 'Inca Tree Malbec 2019',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2019',
#   'size': 750.0,
#   'country': 'Argentina',
#   'wine_type': 'Red Wine',
#   'price': 14.99,
#   'num_review': '50',
#   'rating': '3.5',
#   'url': 'https://www.laithwaites.co.uk/product/Inca-Tree-Malbec-2019/2157519'},
#  {'name': 'Edizione Speciale Numerata Chianti Numero 3 Particella 21 2020',
#   'Mix Case?': 0,
#   'abv': '13.0',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'Italy',
#   'wine_type': 'Red Wine',
#   'price': 16.99,
#   'num_review': '74',
#   'rating': '4.2',
#   'url': 'https://www.laithwaites.co.uk/product/Edizione-Speciale-Numerata-Chianti-Numero-3-Particella-21-2020/3965820'},
#  {'name': 'Cabalié 3 litre Wine Box 2021',
#   'Mix Case?': 0,
#   'abv': '13.0',
#   'year': '2021',
#   'size': 3000.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 30.0,
#   'num_review': '162',
#   'rating': '4.8',
#   'url': 'https://www.laithwaites.co.uk/product/Cabali%C3%A9-3-litre-Wine-Box-2021/4094521'},
#  {'name': 'Tenuta Fenice Nero d’Avola 2021',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Italy',
#   'wine_type': 'Red Wine',
#   'price': 11.99,
#   'num_review': '887',
#   'rating': '4.1',
#   'url': 'https://www.laithwaites.co.uk/product/Tenuta-Fenice-Nero-d%E2%80%99Avola-2021/3147021'},
#  {'name': 'Collezione di Paolo Chianti 2020',
#   'Mix Case?': 0,
#   'abv': '13.0',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'Italy',
#   'wine_type': 'Red Wine',
#   'price': 11.99,
#   'num_review': '387',
#   'rating': '3.7',
#   'url': 'https://www.laithwaites.co.uk/product/Collezione-di-Paolo-Chianti-2020/0019520'},
#  {'name': 'Domaine Saint Martin Cabernet Sauvignon 2020',
#   'Mix Case?': 0,
#   'abv': '14.5',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 9.99,
#   'num_review': '86',
#   'rating': '3.4',
#   'url': 'https://www.laithwaites.co.uk/product/Domaine-Saint-Martin-Cabernet-Sauvignon-2020/3964020'},
#  {'name': 'Finca Libertad Tinto NV',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': 'NV',
#   'size': 750.0,
#   'country': 'Spain',
#   'wine_type': 'Red Wine',
#   'price': 8.49,
#   'num_review': '165',
#   'rating': '3.3',
#   'url': 'https://www.laithwaites.co.uk/product/Finca-Libertad-Tinto-2020/3942020'},
#  {'name': 'Viña del Portillo Reserva 2015',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2015',
#   'size': 750.0,
#   'country': 'Spain',
#   'wine_type': 'Red Wine',
#   'price': 10.99,
#   'num_review': '20',
#   'rating': '3.4',
#   'url': 'https://www.laithwaites.co.uk/product/Vi%C3%B1a-del-Portillo-Reserva-2015/3590115'},
#  {'name': 'Baía de Tróia Castelão 2020',
#   'Mix Case?': 0,
#   'abv': '15.0',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'Portugal',
#   'wine_type': 'Red Wine',
#   'price': 12.99,
#   'num_review': '567',
#   'rating': '4.5',
#   'url': 'https://www.laithwaites.co.uk/product/Ba%C3%ADa-de-Tr%C3%B3ia-Castel%C3%A3o-2020/3497020'},
#  {'name': 'El Bombero 2021',
#   'Mix Case?': 0,
#   'abv': '14.5',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Spain',
#   'wine_type': 'Red Wine',
#   'price': 10.99,
#   'num_review': '2114',
#   'rating': '3.9',
#   'url': 'https://www.laithwaites.co.uk/product/El-Bombero-2021/0003921'},
#  {'name': 'w/o Frappato 2020',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'Italy',
#   'wine_type': 'Red Wine',
#   'price': 11.99,
#   'num_review': '159',
#   'rating': '3.9',
#   'url': 'https://www.laithwaites.co.uk/product/w/o-Frappato-2020/4160220'},
#  {'name': 'Le XV du Président 2021',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 12.99,
#   'num_review': '762',
#   'rating': '4.4',
#   'url': 'https://www.laithwaites.co.uk/product/Le-XV-du-Pr%C3%A9sident-2021/3310021'},
#  {'name': 'The Forefather Gran Selección Malbec Shiraz 2020',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'Argentina',
#   'wine_type': 'Red Wine',
#   'price': 14.99,
#   'num_review': '98',
#   'rating': '4.0',
#   'url': 'https://www.laithwaites.co.uk/product/The-Forefather-Gran-Selecci%C3%B3n-Malbec-Shiraz-2020/0399920'},
#  {'name': 'Don Cayetano Merlot 2021',
#   'Mix Case?': 0,
#   'abv': '12.5',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Chile',
#   'wine_type': 'Red Wine',
#   'price': 8.99,
#   'num_review': '177',
#   'rating': '3.4',
#   'url': 'https://www.laithwaites.co.uk/product/Don-Cayetano-Merlot-2021/0064121'},
#  {'name': 'Il Papavero Primitivo 2020',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'Italy',
#   'wine_type': 'Red Wine',
#   'price': 10.99,
#   'num_review': '696',
#   'rating': '4.1',
#   'url': 'https://www.laithwaites.co.uk/product/Il-Papavero-Primitivo-2020/0121320'},
#  {'name': 'Cleanskin SA Cabernet Sauvignon 2020',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'Australia',
#   'wine_type': 'Red Wine',
#   'price': 14.99,
#   'num_review': '23',
#   'rating': '4.4',
#   'url': 'https://www.laithwaites.co.uk/product/Cleanskin-SA-Cabernet-Sauvignon-2020/4136220'},
#  {'name': 'Project Malbec 2021',
#   'Mix Case?': 0,
#   'abv': '13.0',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Argentina',
#   'wine_type': 'Red Wine',
#   'price': 8.99,
#   'num_review': '127',
#   'rating': '3.8',
#   'url': 'https://www.laithwaites.co.uk/product/Project-Malbec-2021/3980021'},
#  {'name': 'Le Prince de Courthézon Côtes du Rhône 2020',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 12.99,
#   'num_review': '576',
#   'rating': '3.8',
#   'url': 'https://www.laithwaites.co.uk/product/Le-Prince-de-Courth%C3%A9zon-C%C3%B4tes-du-Rh%C3%B4ne-2020/0455720'},
#  {'name': 'Farinelli Rosso NV',
#   'Mix Case?': 0,
#   'abv': '12.5',
#   'year': 'NV',
#   'size': 750.0,
#   'country': 'Italy',
#   'wine_type': 'Red Wine',
#   'price': 7.99,
#   'num_review': '304',
#   'rating': '3.4',
#   'url': 'https://www.laithwaites.co.uk/product/Farinelli-Rosso-2020/2247120'},
#  {'name': 'Miravalles Estate Malbec 2021',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Argentina',
#   'wine_type': 'Red Wine',
#   'price': 8.99,
#   'num_review': '',
#   'rating': '',
#   'url': 'https://www.laithwaites.co.uk/product/Miravalles-Estate-Malbec-2021/4205221'},
#  {'name': "Pillastro Selezione d'Oro 2021",
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Italy',
#   'wine_type': 'Red Wine',
#   'price': 15.49,
#   'num_review': '607',
#   'rating': '4.5',
#   'url': "https://www.laithwaites.co.uk/product/Pillastro-Selezione-d'Oro-2021/0307821"},
#  {'name': "La Fonte d'Oro 2020",
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'Italy',
#   'wine_type': 'Red Wine',
#   'price': 14.99,
#   'num_review': '242',
#   'rating': '4.5',
#   'url': "https://www.laithwaites.co.uk/product/La-Fonte-d'Oro-2020/0307720"},
#  {'name': 'Concettina Rosso 2020',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'Italy',
#   'wine_type': 'Red Wine',
#   'price': 10.99,
#   'num_review': '10',
#   'rating': '4.7',
#   'url': 'https://www.laithwaites.co.uk/product/Concettina-Rosso-2020/4213920'},
#  {'name': 'Hand Select Cleanskin Cabernet Sauvignon 2021',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Australia',
#   'wine_type': 'Red Wine',
#   'price': 16.99,
#   'num_review': '3',
#   'rating': '3.7',
#   'url': 'https://www.laithwaites.co.uk/product/Hand-Select-Cleanskin-Cabernet-Sauvignon-2021/4253321'},
#  {'name': 'Château Le Coin Bordeaux 2020',
#   'Mix Case?': 0,
#   'abv': '14.5',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 13.99,
#   'num_review': '411',
#   'rating': '3.7',
#   'url': 'https://www.laithwaites.co.uk/product/Ch%C3%A2teau-Le-Coin-Bordeaux-2020/0607720'},
#  {'name': 'Boscwood SA Petit Verdot Shiraz 2020',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'Australia',
#   'wine_type': 'Red Wine',
#   'price': 12.99,
#   'num_review': '105',
#   'rating': '3.7',
#   'url': 'https://www.laithwaites.co.uk/product/Boscwood-SA-Petit-Verdot-Shiraz-2020/4063920'},
#  {'name': 'The Waxed Bat (half bottle) 2021',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2021',
#   'size': 375.0,
#   'country': 'Argentina',
#   'wine_type': 'Red Wine',
#   'price': 5.99,
#   'num_review': '',
#   'rating': '',
#   'url': 'https://www.laithwaites.co.uk/product/The-Waxed-Bat-(half-bottle)-2021/4109021'},
#  {'name': 'Tierras de la Fuente Organic Tempranillo Syrah 2020',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'Spain',
#   'wine_type': 'Red Wine',
#   'price': 7.49,
#   'num_review': '214',
#   'rating': '3.2',
#   'url': 'https://www.laithwaites.co.uk/product/Tierras-de-la-Fuente-Organic-Tempranillo-Syrah-2020/3178520'},
#  {'name': 'The Patriots Merlot 2021',
#   'Mix Case?': 0,
#   'abv': '12.5',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Chile',
#   'wine_type': 'Red Wine',
#   'price': 9.99,
#   'num_review': '702',
#   'rating': '3.5',
#   'url': 'https://www.laithwaites.co.uk/product/The-Patriots-Merlot-2021/2257221'},
#  {'name': 'Grant Burge Corryton Park Cabernet Sauvignon 2019',
#   'Mix Case?': 0,
#   'abv': '14.5',
#   'year': '2019',
#   'size': 750.0,
#   'country': 'Australia',
#   'wine_type': 'Red Wine',
#   'price': 30.0,
#   'num_review': '2',
#   'rating': '4.0',
#   'url': 'https://www.laithwaites.co.uk/product/Grant-Burge-Corryton-Park-Cabernet-Sauvignon-2019/4174119'},
#  {'name': 'Mach 2t Cabernet Petit Verdot 2021',
#   'Mix Case?': 0,
#   'abv': '14.5',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Australia',
#   'wine_type': 'Red Wine',
#   'price': 11.99,
#   'num_review': '5',
#   'rating': '4.8',
#   'url': 'https://www.laithwaites.co.uk/product/Mach-2t-Cabernet-Petit-Verdot-2021/4204421'},
#  {'name': 'HJ Fabre Barrel Selection Patagonia Malbec 2020',
#   'Mix Case?': 0,
#   'abv': '14.5',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'Argentina',
#   'wine_type': 'Red Wine',
#   'price': 17.99,
#   'num_review': '241',
#   'rating': '4.2',
#   'url': 'https://www.laithwaites.co.uk/product/HJ-Fabre-Barrel-Selection-Patagonia-Malbec-2020/0232420'},
#  {'name': 'The Dip 2020',
#   'Mix Case?': 0,
#   'abv': '15.0',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'Spain',
#   'wine_type': 'Red Wine',
#   'price': 10.99,
#   'num_review': '205',
#   'rating': '4.2',
#   'url': 'https://www.laithwaites.co.uk/product/The-Dip-2020/4159120'},
#  {'name': 'Santa Magdalena Balduzzi 2020',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'Chile',
#   'wine_type': 'Red Wine',
#   'price': 11.99,
#   'num_review': '219',
#   'rating': '4.3',
#   'url': 'https://www.laithwaites.co.uk/product/Santa-Magdalena-Balduzzi-2020/4025520'},
#  {'name': 'Sancho Garcés Rioja 2020',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'Spain',
#   'wine_type': 'Red Wine',
#   'price': 7.99,
#   'num_review': '17',
#   'rating': '3.5',
#   'url': 'https://www.laithwaites.co.uk/product/Sancho-Garc%C3%A9s-Rioja-2020/4127920'},
#  {'name': 'Familia Martínez Bujanda Reserva 2015',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2015',
#   'size': 750.0,
#   'country': 'Spain',
#   'wine_type': 'Red Wine',
#   'price': 18.99,
#   'num_review': '72',
#   'rating': '3.8',
#   'url': 'https://www.laithwaites.co.uk/product/Familia-Mart%C3%ADnez-Bujanda-Reserva-2015/2151715'},
#  {'name': 'Finca Libertad Tinto NV',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': 'NV',
#   'size': 750.0,
#   'country': 'Spain',
#   'wine_type': 'Red Wine',
#   'price': 8.49,
#   'num_review': '150',
#   'rating': '3.3',
#   'url': 'https://www.laithwaites.co.uk/product/Finca-Libertad-Tinto-2015/3942021'},
#  {'name': 'The Black Stump Reserve Shiraz 2021',
#   'Mix Case?': 0,
#   'abv': '14.5',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Australia',
#   'wine_type': 'Red Wine',
#   'price': 14.99,
#   'num_review': '729',
#   'rating': '4.2',
#   'url': 'https://www.laithwaites.co.uk/product/The-Black-Stump-Reserve-Shiraz-2021/0287221'},
#  {'name': 'Château Moine Vieux Saint-Émilion Grand Cru 2016',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2016',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 22.0,
#   'num_review': '18',
#   'rating': '3.7',
#   'url': 'https://www.laithwaites.co.uk/product/Ch%C3%A2teau-Moine-Vieux-Saint-%C3%89milion-Grand-Cru-2016/4143116'},
#  {'name': 'Mystery Case - Reds', 'Mix Case?': 1},
#  {'name': "La Chiamata Montepulciano d'Abruzzo 2019",
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2019',
#   'size': 750.0,
#   'country': 'Italy',
#   'wine_type': 'Red Wine',
#   'price': 10.99,
#   'num_review': '225',
#   'rating': '4.0',
#   'url': "https://www.laithwaites.co.uk/product/La-Chiamata-Montepulciano-d'Abruzzo-2019/3969819"},
#  {'name': 'Uncle Zin 2019',
#   'Mix Case?': 0,
#   'abv': '14.5',
#   'year': '2019',
#   'size': 750.0,
#   'country': 'Italy',
#   'wine_type': 'Red Wine',
#   'price': 12.99,
#   'num_review': '119',
#   'rating': '4.3',
#   'url': 'https://www.laithwaites.co.uk/product/Uncle-Zin-2019/3684319'},
#  {'name': 'Quinta do Espírito Santo 2020',
#   'Mix Case?': 0,
#   'abv': '15.0',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'Portugal',
#   'wine_type': 'Red Wine',
#   'price': 11.49,
#   'num_review': '685',
#   'rating': '4.0',
#   'url': 'https://www.laithwaites.co.uk/product/Quinta-do-Esp%C3%ADrito-Santo-2020/0061720'},
#  {'name': 'Saracosa Governo Rosso 2021',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Italy',
#   'wine_type': 'Red Wine',
#   'price': 18.49,
#   'num_review': '537',
#   'rating': '4.5',
#   'url': 'https://www.laithwaites.co.uk/product/Saracosa-Governo-Rosso-2021/3119021'},
#  {'name': 'Maison Dominique Piron Beaujolais-Villages 2020',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 14.49,
#   'num_review': '70',
#   'rating': '4.1',
#   'url': 'https://www.laithwaites.co.uk/product/Maison-Dominique-Piron-Beaujolais-Villages-2020/2587020'},
#  {'name': 'Corsiero Nero 2021',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Italy',
#   'wine_type': 'Red Wine',
#   'price': 11.99,
#   'num_review': '1843',
#   'rating': '4.2',
#   'url': 'https://www.laithwaites.co.uk/product/Corsiero-Nero-2021/1541021'},
#  {'name': 'Willy Willy Shiraz 2021',
#   'Mix Case?': 0,
#   'abv': '14.5',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Australia',
#   'wine_type': 'Red Wine',
#   'price': 11.99,
#   'num_review': '1279',
#   'rating': '3.8',
#   'url': 'https://www.laithwaites.co.uk/product/Willy-Willy-Shiraz-2021/0017021'},
#  {'name': 'Purple Duck Pinot Noir 2021',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Australia',
#   'wine_type': 'Red Wine',
#   'price': 11.99,
#   'num_review': '15',
#   'rating': '3.2',
#   'url': 'https://www.laithwaites.co.uk/product/Purple-Duck-Pinot-Noir-2021/4174921'},
#  {'name': 'Willem the Silent 2020',
#   'Mix Case?': 0,
#   'abv': '14.5',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 10.99,
#   'num_review': '236',
#   'rating': '3.7',
#   'url': 'https://www.laithwaites.co.uk/product/Willem-the-Silent-2020/3793820'},
#  {'name': 'Opi Malbec Reserve 2020',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'Argentina',
#   'wine_type': 'Red Wine',
#   'price': 15.99,
#   'num_review': '276',
#   'rating': '4.4',
#   'url': 'https://www.laithwaites.co.uk/product/Opi-Malbec-Reserve-2020/2670020'},
#  {'name': 'Berton All Out Merlot 2021',
#   'Mix Case?': 0,
#   'abv': '14.5',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Australia',
#   'wine_type': 'Red Wine',
#   'price': 10.99,
#   'num_review': '382',
#   'rating': '3.8',
#   'url': 'https://www.laithwaites.co.uk/product/Berton-All-Out-Merlot-2021/1496121'},
#  {'name': "L'Épiphanie de Saint-Émilion Grand Cru 2019",
#   'Mix Case?': 0,
#   'abv': '14.5',
#   'year': '2019',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 40.0,
#   'num_review': '11',
#   'rating': '3.7',
#   'url': "https://www.laithwaites.co.uk/product/L'%C3%89piphanie-de-Saint-%C3%89milion-Grand-Cru-2019/4144619"},
#  {'name': 'Il Basso Merlot 2021',
#   'Mix Case?': 0,
#   'abv': '12.0',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Italy',
#   'wine_type': 'Red Wine',
#   'price': 9.99,
#   'num_review': '259',
#   'rating': '3.3',
#   'url': 'https://www.laithwaites.co.uk/product/Il-Basso-Merlot-2021/3761021'},
#  {'name': 'End of the Line Malbec 2021',
#   'Mix Case?': 0,
#   'abv': '13.0',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Argentina',
#   'wine_type': 'Red Wine',
#   'price': 8.99,
#   'num_review': '157',
#   'rating': '3.6',
#   'url': 'https://www.laithwaites.co.uk/product/End-of-the-Line-Malbec-2021/3471021'},
#  {'name': 'La Cantera Reserva 2017',
#   'Mix Case?': 0,
#   'abv': '14.5',
#   'year': '2017',
#   'size': 750.0,
#   'country': 'Spain',
#   'wine_type': 'Red Wine',
#   'price': 11.99,
#   'num_review': '348',
#   'rating': '3.7',
#   'url': 'https://www.laithwaites.co.uk/product/La-Cantera-Reserva-2017/0825717'},
#  {'name': "Cuvée du Vatican Réserve de l'Abbé Côtes du Rhône 2020",
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 13.99,
#   'num_review': '169',
#   'rating': '3.7',
#   'url': "https://www.laithwaites.co.uk/product/Cuv%C3%A9e-du-Vatican-R%C3%A9serve-de-l'Abb%C3%A9-C%C3%B4tes-du-Rh%C3%B4ne-2020/2266020"},
#  {'name': 'Grande Réserve de Gassac Rouge 2020',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 12.49,
#   'num_review': '201',
#   'rating': '3.8',
#   'url': 'https://www.laithwaites.co.uk/product/Grande-R%C3%A9serve-de-Gassac-Rouge-2020/0086620'},
#  {'name': 'Ixsir Altitudes Rouge 2018',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2018',
#   'size': 750.0,
#   'country': 'Lebanon',
#   'wine_type': 'Red Wine',
#   'price': 20.0,
#   'num_review': '7',
#   'rating': '3.6',
#   'url': 'https://www.laithwaites.co.uk/product/Ixsir-Altitudes-Rouge-2018/4151518'},
#  {'name': 'Vilarissa Valley 2019',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2019',
#   'size': 750.0,
#   'country': 'Portugal',
#   'wine_type': 'Red Wine',
#   'price': 11.99,
#   'num_review': '244',
#   'rating': '4.4',
#   'url': 'https://www.laithwaites.co.uk/product/Vilarissa-Valley-2019/4036719'},
#  {'name': 'Grill House Shiraz Pinotage 2021',
#   'Mix Case?': 0,
#   'abv': '14.5',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'South Africa',
#   'wine_type': 'Red Wine',
#   'price': 12.99,
#   'num_review': '525',
#   'rating': '4.2',
#   'url': 'https://www.laithwaites.co.uk/product/Grill-House-Shiraz-Pinotage-2021/2233621'},
#  {'name': 'Barón de Barbón Reserva 2017',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2017',
#   'size': 750.0,
#   'country': 'Spain',
#   'wine_type': 'Red Wine',
#   'price': 16.99,
#   'num_review': '92',
#   'rating': '3.9',
#   'url': 'https://www.laithwaites.co.uk/product/Bar%C3%B3n-de-Barb%C3%B3n-Reserva-2017/0041017'},
#  {'name': 'Il Brutto Negroamaro Primitivo 2021',
#   'Mix Case?': 0,
#   'abv': '13.0',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Italy',
#   'wine_type': 'Red Wine',
#   'price': 11.99,
#   'num_review': '1097',
#   'rating': '4.1',
#   'url': 'https://www.laithwaites.co.uk/product/Il-Brutto-Negroamaro-Primitivo-2021/2045621'},
#  {'name': 'Senda de los Olivos Crianza 2016',
#   'Mix Case?': 0,
#   'abv': '14.5',
#   'year': '2016',
#   'size': 750.0,
#   'country': 'Spain',
#   'wine_type': 'Red Wine',
#   'price': 19.99,
#   'num_review': '1',
#   'rating': '5.0',
#   'url': 'https://www.laithwaites.co.uk/product/Senda-de-los-Olivos-Crianza-2016/4127216'},
#  {'name': 'Saracosa 2019',
#   'Mix Case?': 0,
#   'abv': '13.0',
#   'year': '2019',
#   'size': 750.0,
#   'country': 'Italy',
#   'wine_type': 'Red Wine',
#   'price': 12.49,
#   'num_review': '434',
#   'rating': '4.1',
#   'url': 'https://www.laithwaites.co.uk/product/Saracosa-2019/0557119'},
#  {'name': 'Rex Mundi Shiraz Grenache Wine Box 2021',
#   'Mix Case?': 0,
#   'abv': '13.0',
#   'year': '2021',
#   'size': 3000.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 30.0,
#   'num_review': '14',
#   'rating': '4.9',
#   'url': 'https://www.laithwaites.co.uk/product/Rex-Mundi-Shiraz-Grenache-Wine-Box-2021/4232821'},
#  {'name': 'Camino de Seda 2021',
#   'Mix Case?': 0,
#   'abv': '15.0',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Spain',
#   'wine_type': 'Red Wine',
#   'price': 11.99,
#   'num_review': '1061',
#   'rating': '3.7',
#   'url': 'https://www.laithwaites.co.uk/product/Camino-de-Seda-2021/1855021'},
#  {'name': 'Mancura Carignan 2018',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2018',
#   'size': 750.0,
#   'country': 'Chile',
#   'wine_type': 'Red Wine',
#   'price': 10.99,
#   'num_review': '1',
#   'rating': '5.0',
#   'url': 'https://www.laithwaites.co.uk/product/Mancura-Carignan-2018/4235518'},
#  {'name': 'RedHeads Coco Rôtie 2019',
#   'Mix Case?': 0,
#   'abv': '14.5',
#   'year': '2019',
#   'size': 750.0,
#   'country': 'Australia',
#   'wine_type': 'Red Wine',
#   'price': 14.99,
#   'num_review': '134',
#   'rating': '3.9',
#   'url': 'https://www.laithwaites.co.uk/product/RedHeads-Coco-R%C3%B4tie-2019/2543019'},
#  {'name': 'Purezza Organic Red 2020',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'Italy',
#   'wine_type': 'Red Wine',
#   'price': 9.99,
#   'num_review': '6',
#   'rating': '4.2',
#   'url': 'https://www.laithwaites.co.uk/product/Purezza-Organic-Red-2020/4214120'},
#  {'name': 'Altos de la Guardia Crianza Rioja 2011',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2011',
#   'size': 750.0,
#   'country': 'Spain',
#   'wine_type': 'Red Wine',
#   'price': 17.99,
#   'num_review': '31',
#   'rating': '3.5',
#   'url': 'https://www.laithwaites.co.uk/product/Altos-de-la-Guardia-Crianza-Rioja-2011/1516111'},
#  {'name': 'Charles Cros 2021',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 11.99,
#   'num_review': '139',
#   'rating': '4.3',
#   'url': 'https://www.laithwaites.co.uk/product/Charles-Cros-2021/3982021'},
#  {'name': 'Langmeil Offspring Cabernet Sauvignon 2018',
#   'Mix Case?': 0,
#   'abv': '15.0',
#   'year': '2018',
#   'size': 750.0,
#   'country': 'Australia',
#   'wine_type': 'Red Wine',
#   'price': 23.0,
#   'num_review': '4',
#   'rating': '3.5',
#   'url': 'https://www.laithwaites.co.uk/product/Langmeil-Offspring-Cabernet-Sauvignon-2018/4178118'},
#  {'name': 'Aluado Alicante Bouschet Reserva 2019',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2019',
#   'size': 750.0,
#   'country': 'Portugal',
#   'wine_type': 'Red Wine',
#   'price': 16.99,
#   'num_review': '95',
#   'rating': '4.3',
#   'url': 'https://www.laithwaites.co.uk/product/Aluado-Alicante-Bouschet-Reserva-2019/3547519'},
#  {'name': 'Long Live The King Cabernet Sauvignon 2021',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Australia',
#   'wine_type': 'Red Wine',
#   'price': 11.99,
#   'num_review': '474',
#   'rating': '3.8',
#   'url': 'https://www.laithwaites.co.uk/product/Long-Live-The-King-Cabernet-Sauvignon-2021/1960721'},
#  {'name': "Andrew's Reserve Shiraz 2020",
#   'Mix Case?': 0,
#   'abv': '14.5',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'Australia',
#   'wine_type': 'Red Wine',
#   'price': 9.99,
#   'num_review': '43',
#   'rating': '4.2',
#   'url': "https://www.laithwaites.co.uk/product/Andrew's-Reserve-Shiraz-2020/4125520"},
#  {'name': 'Il Poeta Barolo 2017',
#   'Mix Case?': 0,
#   'abv': '14.5',
#   'year': '2017',
#   'size': 750.0,
#   'country': 'Italy',
#   'wine_type': 'Red Wine',
#   'price': 27.0,
#   'num_review': '14',
#   'rating': '3.1',
#   'url': 'https://www.laithwaites.co.uk/product/Il-Poeta-Barolo-2017/2114717'},
#  {'name': 'Los Vascos Cabernet Sauvignon Cuvée Especial 2019',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2019',
#   'size': 750.0,
#   'country': 'Chile',
#   'wine_type': 'Red Wine',
#   'price': 14.99,
#   'num_review': '121',
#   'rating': '3.7',
#   'url': 'https://www.laithwaites.co.uk/product/Los-Vascos-Cabernet-Sauvignon-Cuv%C3%A9e-Especial-2019/0929419'},
#  {'name': 'Casa Silva Selección Especial Cabernet Sauvignon Carmenère 2021',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Chile',
#   'wine_type': 'Red Wine',
#   'price': 13.49,
#   'num_review': '19',
#   'rating': '3.9',
#   'url': 'https://www.laithwaites.co.uk/product/Casa-Silva-Selecci%C3%B3n-Especial-Cabernet-Sauvignon-Carmen%C3%A8re-2021/4135221'},
#  {'name': 'Purple Owl Pinot Noir 2021',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'USA',
#   'wine_type': 'Red Wine',
#   'price': 14.99,
#   'num_review': '32',
#   'rating': '3.6',
#   'url': 'https://www.laithwaites.co.uk/product/Purple-Owl-Pinot-Noir-2021/2531521'},
#  {'name': 'Amoras 2020',
#   'Mix Case?': 0,
#   'abv': '13.0',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'Portugal',
#   'wine_type': 'Red Wine',
#   'price': 10.49,
#   'num_review': '686',
#   'rating': '4.1',
#   'url': 'https://www.laithwaites.co.uk/product/Amoras-2020/0287320'},
#  {'name': 'Pigassou 2021',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 10.99,
#   'num_review': '504',
#   'rating': '3.9',
#   'url': 'https://www.laithwaites.co.uk/product/Pigassou-2021/0056321'},
#  {'name': 'Q Malbec 2020',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'Australia',
#   'wine_type': 'Red Wine',
#   'price': 12.99,
#   'num_review': '164',
#   'rating': '4.3',
#   'url': 'https://www.laithwaites.co.uk/product/Q-Malbec-2020/3789520'},
#  {'name': 'le meilleur des 2 mondes 2017',
#   'Mix Case?': 0,
#   'abv': '12.5',
#   'year': '2017',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 19.49,
#   'num_review': '12',
#   'rating': '3.5',
#   'url': 'https://www.laithwaites.co.uk/product/le-meilleur-des-2-mondes-2017/4140117'},
#  {'name': 'Sierra del Plata Malbec 2021',
#   'Mix Case?': 0,
#   'abv': '13.0',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Argentina',
#   'wine_type': 'Red Wine',
#   'price': 10.99,
#   'num_review': '94',
#   'rating': '3.8',
#   'url': 'https://www.laithwaites.co.uk/product/Sierra-del-Plata-Malbec-2021/3755621'},
#  {'name': 'Patronus Barossa Valley Shiraz 2017',
#   'Mix Case?': 0,
#   'abv': '14.5',
#   'year': '2017',
#   'size': 750.0,
#   'country': 'Australia',
#   'wine_type': 'Red Wine',
#   'price': 15.99,
#   'num_review': '2',
#   'rating': '5.0',
#   'url': 'https://www.laithwaites.co.uk/product/Patronus-Barossa-Valley-Shiraz-2017/4185017'},
#  {'name': 'Portmann Cabernet Sauvignon 2020',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'Australia',
#   'wine_type': 'Red Wine',
#   'price': 14.49,
#   'num_review': '10',
#   'rating': '4.1',
#   'url': 'https://www.laithwaites.co.uk/product/Portmann-Cabernet-Sauvignon-2020/4174420'},
#  {'name': 'Rapaura Springs Marlborough Pinot Noir Reserve 2019',
#   'Mix Case?': 0,
#   'abv': '13.0',
#   'year': '2019',
#   'size': 750.0,
#   'country': 'New Zealand',
#   'wine_type': 'Red Wine',
#   'price': 21.0,
#   'num_review': '21',
#   'rating': '3.4',
#   'url': 'https://www.laithwaites.co.uk/product/Rapaura-Springs-Marlborough-Pinot-Noir-Reserve-2019/3757919'},
#  {'name': 'Maison Joseph Drouhin Givry 2018',
#   'Mix Case?': 0,
#   'abv': '13.0',
#   'year': '2018',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 21.0,
#   'num_review': '6',
#   'rating': '4.2',
#   'url': 'https://www.laithwaites.co.uk/product/Maison-Joseph-Drouhin-Givry-2018/0105818'},
#  {'name': 'Château Les Grands Maréchaux 2012',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2012',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 16.99,
#   'num_review': '31',
#   'rating': '4.1',
#   'url': 'https://www.laithwaites.co.uk/product/Ch%C3%A2teau-Les-Grands-Mar%C3%A9chaux-2012/1914112'},
#  {'name': 'Merago 2015',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2015',
#   'size': 750.0,
#   'country': 'Italy',
#   'wine_type': 'Red Wine',
#   'price': 17.99,
#   'num_review': '6',
#   'rating': '3.5',
#   'url': 'https://www.laithwaites.co.uk/product/Merago-2015/4165815'},
#  {'name': 'Capital Z Zinfandel 2020',
#   'Mix Case?': 0,
#   'abv': '15.0',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'USA',
#   'wine_type': 'Red Wine',
#   'price': 14.49,
#   'num_review': '15',
#   'rating': '3.7',
#   'url': 'https://www.laithwaites.co.uk/product/Capital-Z-Zinfandel-2020/3541120'},
#  {'name': 'Ginestières Merlot 2020',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 10.99,
#   'num_review': '826',
#   'rating': '3.7',
#   'url': 'https://www.laithwaites.co.uk/product/Ginesti%C3%A8res-Merlot-2020/0324120'},
#  {'name': 'Château Vartely Dealu Nucului Cabernet Sauvignon 2020',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'Moldova',
#   'wine_type': 'Red Wine',
#   'price': 11.99,
#   'num_review': '444',
#   'rating': '3.7',
#   'url': 'https://www.laithwaites.co.uk/product/Ch%C3%A2teau-Vartely-Dealu-Nucului-Cabernet-Sauvignon-2020/2275120'},
#  {'name': 'Black Duck Durif 2021',
#   'Mix Case?': 0,
#   'abv': '14.5',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Australia',
#   'wine_type': 'Red Wine',
#   'price': 12.99,
#   'num_review': '445',
#   'rating': '3.9',
#   'url': 'https://www.laithwaites.co.uk/product/Black-Duck-Durif-2021/3728821'},
#  {'name': 'The Waxed Bat Reserve 2020',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'Argentina',
#   'wine_type': 'Red Wine',
#   'price': 15.99,
#   'num_review': '455',
#   'rating': '4.3',
#   'url': 'https://www.laithwaites.co.uk/product/The-Waxed-Bat-Reserve-2020/0576220'},
#  {'name': 'Le Secret des Etoiles Pinot Noir 2021',
#   'Mix Case?': 0,
#   'abv': '12.5',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 14.99,
#   'num_review': '37',
#   'rating': '3.8',
#   'url': 'https://www.laithwaites.co.uk/product/Le-Secret-des-Etoiles-Pinot-Noir-2021/1419721'},
#  {'name': 'The Boxer Durif 2020',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'Australia',
#   'wine_type': 'Red Wine',
#   'price': 12.99,
#   'num_review': '363',
#   'rating': '4.2',
#   'url': 'https://www.laithwaites.co.uk/product/The-Boxer-Durif-2020/0061820'},
#  {'name': 'Cabalié Origine 2021',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 16.99,
#   'num_review': '10',
#   'rating': '4.5',
#   'url': 'https://www.laithwaites.co.uk/product/Cabali%C3%A9-Origine-2021/3964821'},
#  {'name': 'William Knuttel Alexander Valley Cabernet Sauvignon 2019',
#   'Mix Case?': 0,
#   'abv': '14.5',
#   'year': '2019',
#   'size': 750.0,
#   'country': 'USA',
#   'wine_type': 'Red Wine',
#   'price': 19.99,
#   'num_review': '8',
#   'rating': '4.4',
#   'url': 'https://www.laithwaites.co.uk/product/William-Knuttel-Alexander-Valley-Cabernet-Sauvignon-2019/4169719'},
#  {'name': 'Château de Colombe Castillon Côtes de Bordeaux 2020',
#   'Mix Case?': 0,
#   'abv': '14.5',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 14.99,
#   'num_review': '91',
#   'rating': '4.3',
#   'url': 'https://www.laithwaites.co.uk/product/Ch%C3%A2teau-de-Colombe-Castillon-C%C3%B4tes-de-Bordeaux-2020/3229220'},
#  {'name': 'Rex Mundi Cuvée Cathare 2021',
#   'Mix Case?': 0,
#   'abv': '14.5',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 17.99,
#   'num_review': '283',
#   'rating': '4.3',
#   'url': 'https://www.laithwaites.co.uk/product/Rex-Mundi-Cuv%C3%A9e-Cathare-2021/3263521'},
#  {'name': 'Aluado Alicante Bouschet (187ml) 2020',
#   'Mix Case?': 0,
#   'abv': '13.0',
#   'year': '2020',
#   'size': 187.0,
#   'country': 'Portugal',
#   'wine_type': 'Red Wine',
#   'price': 3.29,
#   'num_review': '4',
#   'rating': '5.0',
#   'url': 'https://www.laithwaites.co.uk/product/Aluado-Alicante-Bouschet-(187ml)-2020/4105920'},
#  {'name': 'Familia Martínez Bujanda Gran Reserva 2010',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2010',
#   'size': 750.0,
#   'country': 'Spain',
#   'wine_type': 'Red Wine',
#   'price': 21.0,
#   'num_review': '57',
#   'rating': '3.4',
#   'url': 'https://www.laithwaites.co.uk/product/Familia-Mart%C3%ADnez-Bujanda-Gran-Reserva-2010/1495610'},
#  {'name': 'Le Malbec d’Hervé 2021',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 11.99,
#   'num_review': '164',
#   'rating': '4.1',
#   'url': 'https://www.laithwaites.co.uk/product/Le-Malbec-d%E2%80%99Herv%C3%A9-2021/3965621'},
#  {'name': 'Manciata Generosa 2020',
#   'Mix Case?': 0,
#   'abv': '12.5',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'Italy',
#   'wine_type': 'Red Wine',
#   'price': 11.99,
#   'num_review': '94',
#   'rating': '4.0',
#   'url': 'https://www.laithwaites.co.uk/product/Manciata-Generosa-2020/3953820'},
#  {'name': 'Le Géant du Pic 2021',
#   'Mix Case?': 0,
#   'abv': '13.0',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 12.99,
#   'num_review': '7',
#   'rating': '4.6',
#   'url': 'https://www.laithwaites.co.uk/product/Le-G%C3%A9ant-du-Pic-2021/4229321'},
#  {'name': 'El Bombero Gran Reserva 2016',
#   'Mix Case?': 0,
#   'abv': '14.5',
#   'year': '2016',
#   'size': 750.0,
#   'country': 'Spain',
#   'wine_type': 'Red Wine',
#   'price': 13.99,
#   'num_review': '315',
#   'rating': '3.9',
#   'url': 'https://www.laithwaites.co.uk/product/El-Bombero-Gran-Reserva-2016/2177516'},
#  {'name': 'Yarrunga Field Special Reserve Shiraz 2020',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'Australia',
#   'wine_type': 'Red Wine',
#   'price': 10.99,
#   'num_review': '546',
#   'rating': '3.7',
#   'url': 'https://www.laithwaites.co.uk/product/Yarrunga-Field-Special-Reserve-Shiraz-2020/2265520'},
#  {'name': 'T-Bone Malbec 2021',
#   'Mix Case?': 0,
#   'abv': '13.0',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Argentina',
#   'wine_type': 'Red Wine',
#   'price': 9.99,
#   'num_review': '21',
#   'rating': '3.0',
#   'url': 'https://www.laithwaites.co.uk/product/T-Bone-Malbec-2021/4201421'},
#  {'name': 'Castillo Labastida Tempranillo 2021',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Spain',
#   'wine_type': 'Red Wine',
#   'price': 11.99,
#   'num_review': '5',
#   'rating': '3.4',
#   'url': 'https://www.laithwaites.co.uk/product/Castillo-Labastida-Tempranillo-2021/4221021'},
#  {'name': 'Le Coq Léon 2020',
#   'Mix Case?': 0,
#   'abv': '12.5',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 10.99,
#   'num_review': '61',
#   'rating': '3.8',
#   'url': 'https://www.laithwaites.co.uk/product/Le-Coq-L%C3%A9on-2020/3960720'},
#  {'name': 'Pattes Noires Merlot 2019',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2019',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 11.99,
#   'num_review': '48',
#   'rating': '3.7',
#   'url': 'https://www.laithwaites.co.uk/product/Pattes-Noires-Merlot-2019/4215319'},
#  {'name': 'Palacio del Conde Gran Reserva 2014',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2014',
#   'size': 750.0,
#   'country': 'Spain',
#   'wine_type': 'Red Wine',
#   'price': 11.99,
#   'num_review': '582',
#   'rating': '3.4',
#   'url': 'https://www.laithwaites.co.uk/product/Palacio-del-Conde-Gran-Reserva-2014/0002714'},
#  {'name': 'Corsiero Nero Purosangue 2020',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'Italy',
#   'wine_type': 'Red Wine',
#   'price': 17.49,
#   'num_review': '262',
#   'rating': '4.4',
#   'url': 'https://www.laithwaites.co.uk/product/Corsiero-Nero-Purosangue-2020/2641520'},
#  {'name': 'Château Les Aubitriés 2020',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 13.99,
#   'num_review': '4',
#   'rating': '4.5',
#   'url': 'https://www.laithwaites.co.uk/product/Ch%C3%A2teau-Les-Aubitri%C3%A9s-2020/4212820'},
#  {'name': "d'Arenberg Thunderstep Shiraz 2020",
#   'Mix Case?': 0,
#   'abv': '14.5',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'Australia',
#   'wine_type': 'Red Wine',
#   'price': 22.0,
#   'num_review': '2',
#   'rating': '4.5',
#   'url': "https://www.laithwaites.co.uk/product/d'Arenberg-Thunderstep-Shiraz-2020/3961320"},
#  {'name': 'Ultima Edizione NV',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': 'NV',
#   'size': 750.0,
#   'country': 'Italy',
#   'wine_type': 'Red Wine',
#   'price': 12.99,
#   'num_review': '373',
#   'rating': '4.2',
#   'url': 'https://www.laithwaites.co.uk/product/Ultima-Edizione-2020/0232521'},
#  {'name': 'Hacienda de Lluna Shiraz 2020',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'Spain',
#   'wine_type': 'Red Wine',
#   'price': 9.49,
#   'num_review': '157',
#   'rating': '3.0',
#   'url': 'https://www.laithwaites.co.uk/product/Hacienda-de-Lluna-Shiraz-2020/1554520'},
#  {'name': 'La Rioja Alta Viña Ardanza Reserva 2015',
#   'Mix Case?': 0,
#   'abv': '14.5',
#   'year': '2015',
#   'size': 750.0,
#   'country': 'Spain',
#   'wine_type': 'Red Wine',
#   'price': 27.0,
#   'num_review': '7',
#   'rating': '4.6',
#   'url': 'https://www.laithwaites.co.uk/product/La-Rioja-Alta-Vi%C3%B1a-Ardanza-Reserva-2015/2618115'},
#  {'name': 'Domaine La Lirande Syrah 2021',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 12.99,
#   'num_review': '208',
#   'rating': '4.5',
#   'url': 'https://www.laithwaites.co.uk/product/Domaine-La-Lirande-Syrah-2021/3950621'},
#  {'name': 'Stellenrust Heritage Collection Pinotage 2020',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'South Africa',
#   'wine_type': 'Red Wine',
#   'price': 13.49,
#   'num_review': '7',
#   'rating': '4.4',
#   'url': 'https://www.laithwaites.co.uk/product/Stellenrust-Heritage-Collection-Pinotage-2020/2995020'},
#  {'name': 'Palumbo 2021',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Italy',
#   'wine_type': 'Red Wine',
#   'price': 12.99,
#   'num_review': '190',
#   'rating': '4.2',
#   'url': 'https://www.laithwaites.co.uk/product/Palumbo-2021/4035921'},
#  {'name': 'Château du Ragon 2020',
#   'Mix Case?': 0,
#   'abv': '13.0',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 12.99,
#   'num_review': '4',
#   'rating': '3.5',
#   'url': 'https://www.laithwaites.co.uk/product/Ch%C3%A2teau-du-Ragon-2020/4218620'},
#  {'name': 'Château de La Grange Organic 2019',
#   'Mix Case?': 0,
#   'abv': '14.5',
#   'year': '2019',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'Red Wine',
#   'price': 14.49,
#   'num_review': '23',
#   'rating': '4.3',
#   'url': 'https://www.laithwaites.co.uk/product/Ch%C3%A2teau-de-La-Grange-Organic-2019/4096419'},
# ...
#  {'name': 'RedHeads Triplex 2021',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Australia',
#   'wine_type': 'White Wine',
#   'price': 15.99,
#   'num_review': '1',
#   'rating': '4.0',
#   'url': 'https://www.laithwaites.co.uk/product/RedHeads-Triplex-2021/4153221'},
#  {'name': "Blank Canvas 'Abstract' Sauvignon Blanc 2018",
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2018',
#   'size': 750.0,
#   'country': 'New Zealand',
#   'wine_type': 'White Wine',
#   'price': 28.0,
#   'num_review': '',
#   'rating': '',
#   'url': "https://www.laithwaites.co.uk/product/Blank-Canvas-'Abstract'-Sauvignon-Blanc-2018/3758418"},
#  {'name': 'Domaine François Berthenet Montagny 1er Cru Vieilles Vignes 2020',
#   'Mix Case?': 0,
#   'abv': '13.0',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'White Wine',
#   'price': 25.0,
#   'num_review': '',
#   'rating': '',
#   'url': 'https://www.laithwaites.co.uk/product/Domaine-Fran%C3%A7ois-Berthenet-Montagny-1er-Cru-Vieilles-Vignes-2020/3140120'},
#  {'name': 'Happy Birthday Chocolates and White Wine Gift',
#   'Mix Case?': 0,
#   'abv': '12.0',
#   'year': 'Gift',
#   'size': 750.0,
#   'country': 'Italy',
#   'wine_type': 'White Wine',
#   'price': None,
#   'num_review': '',
#   'rating': '4.0',
#   'url': 'https://www.laithwaites.co.uk/product/Happy-Birthday-Chocolates-and-White-Wine-Gift-2020/X13475'},
#  {'name': 'Domaine La Sobilane 2021',
#   'Mix Case?': 0,
#   'abv': '13.0',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'White Wine',
#   'price': 13.49,
#   'num_review': '34',
#   'rating': '4.0',
#   'url': 'https://www.laithwaites.co.uk/product/Domaine-La-Sobilane-2021/4092121'},
#  {'name': 'Sartirano Figli Langhe Nas-cetta 2021',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Italy',
#   'wine_type': 'White Wine',
#   'price': 16.99,
#   'num_review': '2',
#   'rating': '4.5',
#   'url': 'https://www.laithwaites.co.uk/product/Sartirano-Figli-Langhe-Nas-cetta-2021/4205321'},
#  {'name': 'Queen Bee Viognier (magnum) 2021',
#   'Mix Case?': 0,
#   'abv': '12.5',
#   'year': '2021',
#   'size': 1500.0,
#   'country': 'South Africa',
#   'wine_type': 'White Wine',
#   'price': 26.0,
#   'num_review': '23',
#   'rating': '4.5',
#   'url': 'https://www.laithwaites.co.uk/product/Queen-Bee-Viognier-(magnum)-2021/4149721'},
#  {'name': 'Luxury Whites Duo Gift',
#   'Mix Case?': 0,
#   'abv': '13.0',
#   'year': 'Gift',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'White Wine',
#   'price': None,
#   'num_review': '',
#   'rating': '3.8',
#   'url': 'https://www.laithwaites.co.uk/product/Luxury-Whites-Duo-Gift-2021/F10510'},
#  {'name': 'Château Sixtine Châteauneuf-du-Pape Blanc 2020',
#   'Mix Case?': 0,
#   'abv': '14.0',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'White Wine',
#   'price': 31.0,
#   'num_review': '1',
#   'rating': '5.0',
#   'url': 'https://www.laithwaites.co.uk/product/Ch%C3%A2teau-Sixtine-Ch%C3%A2teauneuf-du-Pape-Blanc-2020/2137220'},
#  {'name': 'Claude Lafond La Raie Reuilly Blanc 2021',
#   'Mix Case?': 0,
#   'abv': '12.5',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'White Wine',
#   'price': 15.99,
#   'num_review': '',
#   'rating': '',
#   'url': 'https://www.laithwaites.co.uk/product/Claude-Lafond-La-Raie-Reuilly-Blanc-2021/4245121'},
#  {'name': 'Carmelle Sauvignon Blanc 2020',
#   'Mix Case?': 0,
#   'abv': '12.0',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'White Wine',
#   'price': 11.99,
#   'num_review': '30',
#   'rating': '3.6',
#   'url': 'https://www.laithwaites.co.uk/product/Carmelle-Sauvignon-Blanc-2020/4019120'},
#  {'name': 'Von Reben Riesling 2021',
#   'Mix Case?': 0,
#   'abv': '12.0',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Germany',
#   'wine_type': 'White Wine',
#   'price': 11.99,
#   'num_review': '107',
#   'rating': '3.9',
#   'url': 'https://www.laithwaites.co.uk/product/Von-Reben-Riesling-2021/1826021'},
#  {'name': 'Belle Vague Sauvignon Blanc 2020',
#   'Mix Case?': 0,
#   'abv': '12.0',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'White Wine',
#   'price': 10.99,
#   'num_review': '4',
#   'rating': '2.5',
#   'url': 'https://www.laithwaites.co.uk/product/Belle-Vague-Sauvignon-Blanc-2020/4145420'},
#  {'name': 'Dog Point Organic Chardonnay 2019',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2019',
#   'size': 750.0,
#   'country': 'New Zealand',
#   'wine_type': 'White Wine',
#   'price': 29.0,
#   'num_review': '1',
#   'rating': '5.0',
#   'url': 'https://www.laithwaites.co.uk/product/Dog-Point-Organic-Chardonnay-2019/2378219'},
#  {'name': 'Classic Whites Six Gift',
#   'Mix Case?': 0,
#   'abv': '12.5',
#   'year': 'Gift',
#   'size': 750.0,
#   'country': 'Chile',
#   'wine_type': 'White Wine',
#   'price': None,
#   'num_review': '',
#   'rating': '3.6',
#   'url': 'https://www.laithwaites.co.uk/product/Classic-Whites-Six-Gift-2019/X13482'},
#  {'name': 'Domaine Dubreuil-Fontaine Pernand-Vergelesses Blanc 2020',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'White Wine',
#   'price': 31.0,
#   'num_review': '',
#   'rating': '',
#   'url': 'https://www.laithwaites.co.uk/product/Domaine-Dubreuil-Fontaine-Pernand-Vergelesses-Blanc-2020/1595920'},
#  {'name': 'Domaine Mia Les Plantenays 2019',
#   'Mix Case?': 0,
#   'abv': '13.0',
#   'year': '2019',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'White Wine',
#   'price': 32.0,
#   'num_review': '',
#   'rating': '',
#   'url': 'https://www.laithwaites.co.uk/product/Domaine-Mia-Les-Plantenays-2019/4262719'},
#  {'name': 'Fine Dining Whites Duo Gift',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': 'Gift',
#   'size': 750.0,
#   'country': 'New Zealand',
#   'wine_type': 'White Wine',
#   'price': None,
#   'num_review': '',
#   'rating': '4.3',
#   'url': 'https://www.laithwaites.co.uk/product/Fine-Dining-Whites-Duo-Gift-2019/F10503'},
#  {'name': 'Last Rays of Sun Sauvignons',
#   'Mix Case?': 0,
#   'abv': '11.5',
#   'year': 'Sauvignons',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'White Wine',
#   'price': None,
#   'num_review': '',
#   'rating': '3.8',
#   'url': 'https://www.laithwaites.co.uk/product/Last-Rays-of-Sun-Sauvignons-2019/X13546'},
#  {'name': "Fisherman's Return 2021",
#   'Mix Case?': 0,
#   'abv': '12.0',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'White Wine',
#   'price': 12.99,
#   'num_review': '',
#   'rating': '',
#   'url': "https://www.laithwaites.co.uk/product/Fisherman's-Return-2021/4249221"},
#  {'name': 'Friday Night Merlots',
#   'Mix Case?': 0,
#   'abv': '12.5',
#   'year': 'Merlots',
#   'size': 750.0,
#   'country': 'Chile',
#   'wine_type': 'White Wine',
#   'price': None,
#   'num_review': '',
#   'rating': '3.5',
#   'url': 'https://www.laithwaites.co.uk/product/Friday-Night-Merlots-2021/X13543'},
#  {'name': 'Domaine Bertagna Bourgogne Blanc Les Croix Blanches 2020',
#   'Mix Case?': 0,
#   'abv': '0.99',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'White Wine',
#   'price': 22.0,
#   'num_review': '',
#   'rating': '',
#   'url': 'https://www.laithwaites.co.uk/product/Domaine-Bertagna-Bourgogne-Blanc-Les-Croix-Blanches-2020/4121120'},
#  {'name': 'Hosting a Houseful White Wines',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': 'Wines',
#   'size': 750.0,
#   'country': 'South Africa',
#   'wine_type': 'White Wine',
#   'price': None,
#   'num_review': '',
#   'rating': '4.4',
#   'url': 'https://www.laithwaites.co.uk/product/Hosting-a-Houseful-White-Wines-2020/X13493'},
#  {'name': 'Domaine Saint André Sauvignon Blanc 2021',
#   'Mix Case?': 0,
#   'abv': '12.0',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'White Wine',
#   'price': 12.99,
#   'num_review': '',
#   'rating': '',
#   'url': 'https://www.laithwaites.co.uk/product/Domaine-Saint-Andr%C3%A9-Sauvignon-Blanc-2021/4220521'},
#  {'name': 'Fine Dining Whites Six Gift',
#   'Mix Case?': 0,
#   'abv': '11.0',
#   'year': 'Gift',
#   'size': 750.0,
#   'country': 'Italy',
#   'wine_type': 'White Wine',
#   'price': None,
#   'num_review': '',
#   'rating': '4.5',
#   'url': 'https://www.laithwaites.co.uk/product/Fine-Dining-Whites-Six-Gift/X12560'},
#  {'name': 'Chapoutier les Tanneurs Saint-Péray Blanc 2020',
#   'Mix Case?': 0,
#   'abv': 'TBC',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'White Wine',
#   'price': None,
#   'num_review': '',
#   'rating': '',
#   'url': 'https://www.laithwaites.co.uk/product/Chapoutier-les-Tanneurs-Saint-P%C3%A9ray-Blanc-2020/1637120'},
#  {'name': 'South African Whites Mix', 'Mix Case?': 1},
#  {'name': 'Domaine Matrot Saint-Romain 2020',
#   'Mix Case?': 0,
#   'abv': 'TBC',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'White Wine',
#   'price': None,
#   'num_review': '',
#   'rating': '',
#   'url': 'https://www.laithwaites.co.uk/product/Domaine-Matrot-Saint-Romain-2020/4225820'},
#  {'name': 'Domaine de la Vougeraie Côte de Beaune Les Pierres Blanches Organic 2020',
#   'Mix Case?': 0,
#   'abv': 'TBC',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'White Wine',
#   'price': None,
#   'num_review': '',
#   'rating': '',
#   'url': 'https://www.laithwaites.co.uk/product/Domaine-de-la-Vougeraie-C%C3%B4te-de-Beaune-Les-Pierres-Blanches-Organic-2020/3543220'},
#  {'name': 'Italian Whites Six',
#   'Mix Case?': 0,
#   'abv': '12.5',
#   'year': 'Six',
#   'size': 750.0,
#   'country': 'Italy',
#   'wine_type': 'White Wine',
#   'price': None,
#   'num_review': '',
#   'rating': '4.0',
#   'url': 'https://www.laithwaites.co.uk/product/Italian-Whites-Six-2020/X13806'},
#  {'name': 'Château Clos Haut-Peyraguey (half bottle) 2021',
#   'Mix Case?': 0,
#   'abv': 'TBC',
#   'year': '2021',
#   'size': 375.0,
#   'country': 'France',
#   'wine_type': 'White Wine',
#   'price': None,
#   'num_review': '',
#   'rating': '',
#   'url': 'https://www.laithwaites.co.uk/product/Ch%C3%A2teau-Clos-Haut-Peyraguey-(half-bottle)-2021/4151321'},
#  {'name': 'Domaine Matrot Meursault 2020',
#   'Mix Case?': 0,
#   'abv': 'TBC',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'White Wine',
#   'price': None,
#   'num_review': '1',
#   'rating': '2.0',
#   'url': 'https://www.laithwaites.co.uk/product/Domaine-Matrot-Meursault-2020/1535320'},
#  {'name': 'Von Buhl Pechstein Grosses Gewächs Organic 2019',
#   'Mix Case?': 0,
#   'abv': 'TBC',
#   'year': '2019',
#   'size': 750.0,
#   'country': 'Germany',
#   'wine_type': 'White Wine',
#   'price': None,
#   'num_review': '',
#   'rating': '',
#   'url': 'https://www.laithwaites.co.uk/product/Von-Buhl-Pechstein-Grosses-Gew%C3%A4chs-Organic-2019/2512219'},
#  {'name': 'Ferraton Père et Fils Les Oliviers Saint-Joseph Blanc 2020',
#   'Mix Case?': 0,
#   'abv': 'TBC',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'White Wine',
#   'price': None,
#   'num_review': '',
#   'rating': '',
#   'url': 'https://www.laithwaites.co.uk/product/Ferraton-P%C3%A8re-et-Fils-Les-Oliviers-Saint-Joseph-Blanc-2020/2988120'},
#  {'name': 'Guigal Côtes du Rhône Blanc 2020',
#   'Mix Case?': 0,
#   'abv': 'TBC',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'White Wine',
#   'price': None,
#   'num_review': '5',
#   'rating': '4.4',
#   'url': 'https://www.laithwaites.co.uk/product/Guigal-C%C3%B4tes-du-Rh%C3%B4ne-Blanc-2020/2139520'},
#  {'name': 'Refreshing Whites Wine Box Trio',
#   'Mix Case?': 0,
#   'abv': '11.5',
#   'year': 'Trio',
#   'size': 3000.0,
#   'country': 'South Africa',
#   'wine_type': 'White Wine',
#   'price': None,
#   'num_review': '',
#   'rating': '3.5',
#   'url': 'https://www.laithwaites.co.uk/product/Refreshing-Whites-Wine-Box-Trio-2020/J10437'},
#  {'name': 'Von Buhl Kieselberg Grosses Gewächs Organic 2019',
#   'Mix Case?': 0,
#   'abv': 'TBC',
#   'year': '2019',
#   'size': 750.0,
#   'country': 'Germany',
#   'wine_type': 'White Wine',
#   'price': None,
#   'num_review': '',
#   'rating': '',
#   'url': 'https://www.laithwaites.co.uk/product/Von-Buhl-Kieselberg-Grosses-Gew%C3%A4chs-Organic-2019/3064119'},
#  {'name': 'Château La Garde Blanc 2020',
#   'Mix Case?': 0,
#   'abv': 'TBC',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'White Wine',
#   'price': None,
#   'num_review': '',
#   'rating': '',
#   'url': 'https://www.laithwaites.co.uk/product/Ch%C3%A2teau-La-Garde-Blanc-2020/3300020'},
#  {'name': 'Fray Leon Sauvignon Blanc Reserva 2022',
#   'Mix Case?': 0,
#   'abv': '13.0',
#   'year': '2022',
#   'size': 750.0,
#   'country': 'Chile',
#   'wine_type': 'White Wine',
#   'price': 12.99,
#   'num_review': '26',
#   'rating': '4.2',
#   'url': 'https://www.laithwaites.co.uk/product/Fray-Leon-Sauvignon-Blanc-Reserva-2022/4131922'},
#  {'name': 'Reichsrat Von Buhl Kirchenstück Grosses Gewächs Organic 2019',
#   'Mix Case?': 0,
#   'abv': 'TBC',
#   'year': '2019',
#   'size': 750.0,
#   'country': 'Germany',
#   'wine_type': 'White Wine',
#   'price': None,
#   'num_review': '',
#   'rating': '',
#   'url': 'https://www.laithwaites.co.uk/product/Reichsrat-Von-Buhl-Kirchenst%C3%BCck-Grosses-Gew%C3%A4chs-Organic-2019/2512319'},
#  {'name': 'Domaine Joseph Colin Bourgogne Blanc La Combe 2020',
#   'Mix Case?': 0,
#   'abv': 'TBC',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'White Wine',
#   'price': None,
#   'num_review': '',
#   'rating': '',
#   'url': 'https://www.laithwaites.co.uk/product/Domaine-Joseph-Colin-Bourgogne-Blanc-La-Combe-2020/3776820'},
#  {'name': 'Chardonnay Six',
#   'Mix Case?': 0,
#   'abv': '12.0',
#   'year': 'Six',
#   'size': 750.0,
#   'country': 'Australia',
#   'wine_type': 'White Wine',
#   'price': None,
#   'num_review': '',
#   'rating': '3.7',
#   'url': 'https://www.laithwaites.co.uk/product/Chardonnay-Six-2020/X13807'},
#  {'name': 'Château Talbot Caillou Blanc 2021',
#   'Mix Case?': 0,
#   'abv': 'TBC',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'White Wine',
#   'price': None,
#   'num_review': '',
#   'rating': '',
#   'url': 'https://www.laithwaites.co.uk/product/Ch%C3%A2teau-Talbot-Caillou-Blanc-2021/3623521'},
#  {'name': "Benjamin Leroux  Chassagne Montrachet 1er Cru 'Abbaye de Morgeot' 2020",
#   'Mix Case?': 0,
#   'abv': 'TBC',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'White Wine',
#   'price': None,
#   'num_review': '',
#   'rating': '',
#   'url': "https://www.laithwaites.co.uk/product/Benjamin-Leroux--Chassagne-Montrachet-1er-Cru-'Abbaye-de-Morgeot'-2020/4227920"},
#  {'name': 'Nelson Bay Sauvignon Blanc 2022',
#   'Mix Case?': 0,
#   'abv': '13.0',
#   'year': '2022',
#   'size': 750.0,
#   'country': 'New Zealand',
#   'wine_type': 'White Wine',
#   'price': 13.99,
#   'num_review': '',
#   'rating': '',
#   'url': 'https://www.laithwaites.co.uk/product/Nelson-Bay-Sauvignon-Blanc-2022/3805722'},
#  {'name': 'Château Malartic Lagravière Blanc 2021',
#   'Mix Case?': 0,
#   'abv': 'TBC',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'White Wine',
#   'price': None,
#   'num_review': '',
#   'rating': '',
#   'url': 'https://www.laithwaites.co.uk/product/Ch%C3%A2teau-Malartic-Lagravi%C3%A8re-Blanc-2021/0960621'},
#  {'name': 'Viognier Mix', 'Mix Case?': 1},
#  {'name': 'New Zealand Sauvignon Six',
#   'Mix Case?': 0,
#   'abv': '13.5',
#   'year': 'Six',
#   'size': 750.0,
#   'country': 'New Zealand',
#   'wine_type': 'White Wine',
#   'price': None,
#   'num_review': '',
#   'rating': '4.3',
#   'url': 'https://www.laithwaites.co.uk/product/New-Zealand-Sauvignon-Six-2021/X13825'},
#  {'name': 'Southern French Whites Mix', 'Mix Case?': 1},
#  {'name': 'Naegele Riesling Trocken Fass Nr. 98 2021',
#   'Mix Case?': 0,
#   'abv': '12.0',
#   'year': '2021',
#   'size': 750.0,
#   'country': 'Germany',
#   'wine_type': 'White Wine',
#   'price': 14.99,
#   'num_review': '36',
#   'rating': '4.1',
#   'url': 'https://www.laithwaites.co.uk/product/Naegele-Riesling-Trocken-Fass-Nr.-98-2021/0239321'},
#  {'name': 'Maison Roche de Bellene Chassagne-Montrachet 2020',
#   'Mix Case?': 0,
#   'abv': 'TBC',
#   'year': '2020',
#   'size': 750.0,
#   'country': 'France',
#   'wine_type': 'White Wine',
#   'price': None,
#   'num_review': '',
#   'rating': '',
#   'url': 'https://www.laithwaites.co.uk/product/Maison-Roche-de-Bellene-Chassagne-Montrachet-2020/3151520'},
#  ...]

# %%
df = pd.DataFrame(wine_info_all)

export_path = './data/scrapped/laithwaites_listings.csv'
df.to_csv(export_path, index=False)
