# %%
from mpl_toolkits import mplot3d
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
import pycountry

# %%
# upload the dataset of laithwaites
laithwaites_df = pd.read_csv('laithwaites_to_merge.csv')
laithwaites_df.rename(columns={"size" : 'size(cL)'}, inplace = True)
laithwaites_df.head(20)
# Out:
#     Unnamed: 0                                               name  \
# 0            0                                      Cabalié 2021
# 1            1                 The Black Stump Durif Shiraz 2021
# 2            2                        Vinha do Fava Reserva 2020
# 3            3                         w/o Organic Frappato 2021
# 4            4                          Pillastro Primitivo 2020
# 5            5                     Aluado Alicante Bouschet 2021
# 6            6                       Farinelli Pinot Grigio 2021
# 7            7                                Cabalié Blanc 2021
# 8            8            Hacienda de Lluna Moscatel Rosado 2021
# 9            9               Brezza Bianca Frizzante Prosecco NV
# 10          10                Lobster Shack Sauvignon Blanc 2022
# 11          11   The Great Bonza Reserve Shiraz Cabernet Sauvi...
# 12          12                      Abbesse Sauvignon Blanc 2021
# ...

# %%
# check the laithwaites NA value
laithwaites_df.isna().sum()
# Out:
# Unnamed: 0      0
# name            0
# country         0
# wine_type       0
# year           64
# scaledprice     0
# score           0
# num_review      0
# abv             1
# age            64
# size(cL)        0
# logprice        0
# price           0
# dtype: int64

# %% [markdown]
# # Decantlo

# %%
# upload the dataset of decantlo
Decantlo_df = pd.read_csv('#input your file pathway#')
Decantlo_df.head(20)

# %%
# check the Decantlo NA value
Decantlo_df.isna().sum()

# %% [markdown]
# # morrissons

# %%
# upload the dataset of morrissons
morrissons_df = pd.read_csv('#input your file pathway#')
morrissons_df.head(20)

# %%
# check the morrissons NA value
morrissons_df.isna().sum()

# %% [markdown]
# # Merge them together

# %%
# get the merge dataset
list = [morrissons_df, laithwaites_df, Decantlo_df]
dataset_merge = pd.concat(list)
dataset_merge

# %%
# check the NA value of the merge dataset
dataset_merge.isna().sum()

# Don't forget to check that NA value is equal to total NA value of above dataset.
