# %%
# Import necessary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer

# %%
# Load dataset into a dataframe
data = pd.read_csv("./data/scrapped/morrissons_listings.csv")
data.head()
# Out:
#   wine_type  size (cL)                                              name  \
# 0     white       75.0                       McGuigan Black Label Shiraz
# 1     white       75.0                  Morrisons The Best Touraine Rose
# 2     white       75.0                       McGuigan Black Label Merlot
# 3     white       75.0  Morrisons The Best South African Sauvignon Blanc
# 4     white       75.0                    Hardys Nottage Hill Chardonnay
#
#    price  rating  num_review       country   abv  year  \
# 0   6.75     3.6          13     Australia  12.5  2021
# 1   8.00     3.0           4        France  12.5   NaN
# 2   6.75     4.2          13     Australia  12.5  2021
# 3   7.50     4.0           9  Western Cape  12.5  2021
# 4   6.75     3.4           5     Australia  13.5  2017
#
#                                                  url
# 0  https://groceries.morrisons.com/products/mcgui...
# 1  https://groceries.morrisons.com/products/morri...
# 2  https://groceries.morrisons.com/products/mcgui...
# 3  https://groceries.morrisons.com/products/morri...
# 4  https://groceries.morrisons.com/products/hardy...

# %%
# IMPLEMENT THE FIX
# Rename the column name for convenience
data.rename(columns={"size (cL)" : "size"}, inplace=True)

# %%
# Check types of all variables
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 518 entries, 0 to 517
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   wine_type   518 non-null    object
#  1   size        518 non-null    float64
#  2   name        518 non-null    object
#  3   price       518 non-null    float64
#  4   rating      518 non-null    float64
#  5   num_review  518 non-null    int64
#  6   country     496 non-null    object
#  7   abv         509 non-null    float64
#  8   year        416 non-null    object
#  9   url         518 non-null    object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 40.6+ KB

# %%
# Count NA values
data.isna().sum()
# Out:
# wine_type       0
# size            0
# name            0
# price           0
# rating          0
# num_review      0
# country        22
# abv             9
# year          102
# url             0
# dtype: int64

# %%
# Check number of unique values in all columns
data.nunique()
# Out:
# wine_type       5
# size            9
# name          490
# price          81
# rating         35
# num_review     29
# country        32
# abv            28
# year           13
# url           501
# dtype: int64

# %%
# Histogram plots for rating
sns.set(rc={"figure.figsize":(6,6)})
sns.histplot(data.query('num_review > 0')["rating"])
plt.show()

# %%
# Histogram plots for number of reviews. There are some extreme values at the end
sns.set(rc={"figure.figsize":(6,6)})
sns.histplot(data.query('num_review > 0')["num_review"], kde=False, bins=50)
plt.show()

# %%
# Histogram plots for number of reviews, without the extreme values. Still very skewed
sns.set(rc={"figure.figsize":(6,6)})
sns.histplot(data.query('num_review > 0 and num_review < 50')["num_review"], kde=False, bins=50)
plt.show()

# %%
# Histogram plots for wine type
sns.set(rc={"figure.figsize":(10,6)})
sns.histplot(data["wine_type"])
plt.show()

# %%
# Histogram plots for size
sns.set(rc={"figure.figsize":(6,6)})
sns.histplot(data["size"], kde=False, bins=50)
plt.show()

# %%
# Number of bottles by size. Most are 75 cl.
data.groupby('size').size()
# Out:
# size
# 12.5       1
# 18.7      10
# 20.0       3
# 37.5       6
# 70.0       9
# 75.0     462
# 100.0     14
# 150.0      6
# 225.0      7
# dtype: int64

# %%
# IMPLEMENT THE FIX
# Fix missing countries to unknown value
data["country"].fillna("unknown" , inplace=True)
data["country"].unique()
# Out:
# array(['Australia', 'France', 'Western Cape', 'New Zealand', 'Italy',
#        'Chile', 'South Africa', 'Hungary', 'unknown', 'Spain',
#        'California', 'Produce of the EU', 'United States', 'Austria',
#        'Portugal', 'Western Australia', 'Germany', 'Argentina', 'U',
#        'Marlborough', 'British', 'Bulgaria', 'United Kingdom', 'England',
#        'Moldova (Republic Of)', 'USA', 'Valle Central', 'Bordeaux',
#        'Greece', 'Cahors', 'Scotland', ': Portugal',
#        'the Island of Madeira'], dtype=object)

# %%
# Histogram plot of ABV
sns.set(rc={"figure.figsize":(6,6)})
sns.histplot(data["abv"], kde=False,bins=50)
plt.show()

# %%
# Compute % of missing values
print('Missing pct', data["abv"].isna().sum()/len(data["abv"])*100)
# Out:
# Missing pct 1.7374517374517375

# %%
# As the % of missing values is very small, we will drop the rows having abv value as NA
data.dropna(subset = ["abv"], inplace=True)

# %%
# Histogram plot of year
sns.set(rc={"figure.figsize":(14,7)})
sns.histplot(data["year"], bins=30)
plt.show()

# %%
# The missing pct is >20%. We need to see if there's any pattern
print('Missing pct', data["year"].isna().sum()/len(data["year"])*100)
# Out:
# Missing pct 19.05697445972495

# %%
data['missing_year'] = data['year'].isnull()
data['price_bucket'] = pd.qcut(data['price'], 10)

# %%
# Histogram plot of year
for col in ['wine_type', 'country', 'price_bucket']:
    fig, axs = plt.subplots(figsize=(14, 7))
    # sns.histplot(data.query('not missing_year')['wine_type'], bins=30, ax=axs, alpha=.5)
    # sns.histplot(data.query('missing_year')['wine_type'], bins=30, ax=axs, alpha=.5, color='red')
    sns.countplot(data=data, x=col, ax=axs, alpha=.5, hue='missing_year')
    axs.set_title(f'Missing values - {col}')
    plt.xticks(rotation=45)
    plt.show()

# %%
# Feature Engineering
data = data.reset_index(drop=True)

def get_age(year):
    try:
        return 2022 - int(year)
    except:
        return None

# Find age
data.loc[:, "age"] = data['year'].apply(get_age)

# Creating a column with ratings >5
for i, num in enumerate(data["num_review"]):
    if num > 5:
        data.loc[i, "score"] = data.loc[i, "rating"]
    else:
        data.loc[i, "score"] = 0

# %%
# Impute size to most frequent value
# That is 75cl which is reasonable
impute = SimpleImputer(missing_values=np.nan, strategy="most_frequent")
data[["size"]]=impute.fit_transform(data[["size"]])

# To scale size --> Price per cl
for i, size in enumerate(data["size"]):
    data.loc[i, "scaledprice"] = data.loc[i, "price"] * 75 / size

# Creating a new column log price as it is skewed
# Doesn't make sense
data.loc[:, "logprice"] = np.log10(data.loc[:,"scaledprice"])

# %%
# creating country codes
import pycountry

# create a dict f country name and their codes 
countries = {}
for country in pycountry.countries:
    countries[country.name] = country.alpha_3

data["countrycode"] = [countries.get(c, "unknown") for c in data["country"]]
data.head()
# Out:
#   wine_type  size                                              name  price  \
# 0     white  75.0                       McGuigan Black Label Shiraz   6.75
# 1     white  75.0                  Morrisons The Best Touraine Rose   8.00
# 2     white  75.0                       McGuigan Black Label Merlot   6.75
# 3     white  75.0  Morrisons The Best South African Sauvignon Blanc   7.50
# 4     white  75.0                    Hardys Nottage Hill Chardonnay   6.75
#
#    rating  num_review       country   abv  year  \
# 0     3.6          13     Australia  12.5  2021
# 1     3.0           4        France  12.5   NaN
# 2     4.2          13     Australia  12.5  2021
# 3     4.0           9  Western Cape  12.5  2021
# 4     3.4           5     Australia  13.5  2017
#
#                                                  url  missing_year  \
# 0  https://groceries.morrisons.com/products/mcgui...         False
# 1  https://groceries.morrisons.com/products/morri...          True
# 2  https://groceries.morrisons.com/products/mcgui...         False
# 3  https://groceries.morrisons.com/products/morri...         False
# 4  https://groceries.morrisons.com/products/hardy...         False
#
#   price_bucket  age  score  scaledprice  logprice countrycode
# 0   (6.5, 7.0]  1.0    3.6         6.75  0.829304         AUS
# 1  (7.75, 8.5]  NaN    0.0         8.00  0.903090         FRA
# 2   (6.5, 7.0]  1.0    4.2         6.75  0.829304         AUS
# 3  (7.0, 7.75]  1.0    4.0         7.50  0.875061     unknown
# 4   (6.5, 7.0]  5.0    0.0         6.75  0.829304         AUS

# %%
# price visualisation (log plot of price as the data is skewed)
sns.set(rc={"figure.figsize":(5,5)})

sns.boxplot(data=np.log10(data["scaledprice"]), color= "red")
# Out:
# <AxesSubplot:>

# %%
price_dropna = pd.to_numeric(data["price"], errors='coerce')

# price visualisation. Remove the single outlier: £26000 bottle
sns.set(rc={"figure.figsize":(5,6)})

sns.boxplot(data=price_dropna[price_dropna < 20000], color= "red")
# Out:
# <AxesSubplot:>

# %%
# price visualisation. Remove the single outlier: £26000 bottle
sns.set(rc={"figure.figsize":(5,6)})

sns.boxplot(data=price_dropna[price_dropna < 100], color= "red")
# Out:
# <AxesSubplot:>

# %%
# Countries visualisation
# BREAK DOWN BY WINE TYPE
sns.set(rc={"figure.figsize":(10,10)})
sns.histplot(data=data, y="country", hue="country")
# Out:
# <AxesSubplot:xlabel='Count', ylabel='country'>

# %%
# plot wine type vs abs price
data['price_fixed'] = pd.to_numeric(data['price'], errors='coerce')


sns.set(rc={"figure.figsize":(15,7)})

sns.boxplot(
    data=data.query('price_fixed < 100'),
    x="wine_type", y="price_fixed", hue="wine_type"
)

plt.title('Morrissons Price distribution by wine category - Listed price')
# Out:
# Text(0.5, 1.0, 'Morrissons Price distribution by wine category - Listed price')

# %%
# plot wine type vs price

sns.set(rc={"figure.figsize":(15,7)})

sns.boxplot(
    data=data,
    x="wine_type", y="logprice", hue="wine_type"
)

plt.title('Morrissons Price distribution by wine category - Log tranformed')
# Out:
# Text(0.5, 1.0, 'Morrissons Price distribution by wine category - Log tranformed')

# %%
# plot country vs review ratings
sns.catplot(
    data=data.query('num_review > 0').loc[data["countrycode"]!="unknown"], 
    x="countrycode", 
    y="score", 
    height=4, 
    aspect=3,
)

# %%
sns.scatterplot(
    data=data.query('num_review > 0'), 
    hue='score', 
    x='age', 
    y='logprice', 
    alpha=.5, 
    palette='flare',
)
# Out:
# <AxesSubplot:xlabel='age', ylabel='logprice'>

# %%
# Plot log price vs age and rating

from mpl_toolkits import mplot3d

fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot3D(data["score"], data["age"], data["logprice"], '.')
ax.set_xlabel("Rating")
ax.set_ylabel("Age")
ax.set_zlabel("LogPrice")
# Out:
# Text(0.5, 0, 'LogPrice')

# %%
# Plot top 5 frequent years
topyear=data.loc[:, "year"].value_counts().sort_values(ascending=False)
top=topyear.iloc[0:5]
topy =pd.DataFrame({'year':top.index, 'count':top.values})
topy
# Out:
#    year  count
# 0    NV    100
# 1  2020     76
# 2  2021     70
# 3  2019     69
# 4  2017     20

# %%
sns.set(rc={"figure.figsize":(6,6)})
sns.barplot(data=topy, x= "year", y = "count")
# Out:
# <AxesSubplot:xlabel='year', ylabel='count'>

# %%
# Rename the column name for convenience
data.rename(columns={"size" : "size(cL)", "scaledprice" : "scaled_price" }, inplace=True)
data
# Out:
#                wine_type  size(cL)  \
# 0                  white      75.0
# 1                  white      75.0
# 2                  white      75.0
# 3                  white      75.0
# 4                  white      75.0
# ..                   ...       ...
# 504  fortified_and_other      75.0
# 505  fortified_and_other      70.0
# 506  fortified_and_other      75.0
# 507  fortified_and_other      75.0
# 508  fortified_and_other      75.0
#
#                                                  name  price  rating  \
# 0                         McGuigan Black Label Shiraz   6.75     3.6
# 1                    Morrisons The Best Touraine Rose   8.00     3.0
# 2                         McGuigan Black Label Merlot   6.75     4.2
# 3    Morrisons The Best South African Sauvignon Blanc   7.50     4.0
# 4                      Hardys Nottage Hill Chardonnay   6.75     3.4
# ..                                                ...    ...     ...
# 504                           Cornish Blackberry Mead   8.75     3.0
# 505                     Sanatogen Original Tonic Wine   5.75     4.5
# 506                      Gonzalez Byass Tio Pepe Fino  11.00     0.0
# 507                Taylor's Late Bottled Vintage Port  16.00     3.7
# 508                       Morrisons The Best LBV Port  11.50     3.5
#
#      num_review         country   abv  year  \
# 0            13       Australia  12.5  2021
# 1             4          France  12.5   NaN
# 2            13       Australia  12.5  2021
# 3             9    Western Cape  12.5  2021
# 4             5       Australia  13.5  2017
# ..          ...             ...   ...   ...
# 504           6  United Kingdom  17.0    NV
# 505           2         unknown  15.0    NV
# 506           0           Spain  15.0    NV
# 507           3        Portugal  20.0  2014
# 508           4        Portugal  20.0   NaN
#
#                                                    url  missing_year  \
# 0    https://groceries.morrisons.com/products/mcgui...         False
# 1    https://groceries.morrisons.com/products/morri...          True
# 2    https://groceries.morrisons.com/products/mcgui...         False
# 3    https://groceries.morrisons.com/products/morri...         False
# 4    https://groceries.morrisons.com/products/hardy...         False
# ..                                                 ...           ...
# 504  https://groceries.morrisons.com/products/corni...         False
# 505  https://groceries.morrisons.com/products/sanat...         False
# 506  https://groceries.morrisons.com/products/gonza...         False
# 507  https://groceries.morrisons.com/products/taylo...         False
# 508  https://groceries.morrisons.com/products/morri...          True
#
#      price_bucket  scaled_price  logprice countrycode  price_fixed  age  score
# 0      (6.5, 7.0]      6.750000  0.829304         AUS         6.75  1.0    3.6
# 1     (7.75, 8.5]      8.000000  0.903090         FRA         8.00  NaN    0.0
# 2      (6.5, 7.0]      6.750000  0.829304         AUS         6.75  1.0    4.2
# 3     (7.0, 7.75]      7.500000  0.875061     unknown         7.50  1.0    4.0
# 4      (6.5, 7.0]      6.750000  0.829304         AUS         6.75  5.0    0.0
# ..            ...           ...       ...         ...          ...  ...    ...
# 504    (8.5, 9.0]      8.750000  0.942008         GBR         8.75  NaN    3.0
# 505   (4.99, 6.0]      6.160714  0.789631     unknown         5.75  NaN    0.0
# 506  (10.0, 14.0]     11.000000  1.041393         ESP        11.00  NaN    0.0
# 507  (14.0, 56.0]     16.000000  1.204120         PRT        16.00  8.0    0.0
# 508  (10.0, 14.0]     11.500000  1.060698         PRT        11.50  NaN    0.0
#
# [509 rows x 18 columns]

# %%
data.drop(['missing_year', 'price_bucket'], axis=1).to_csv("./data/ready to merge/morrissons_to_merge.csv", index=False)
